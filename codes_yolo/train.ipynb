# %%
dataset_path = "./data"
# !yolo classify train data={dataset_path} model=yolov8s-cls.pt epochs=100 imgsz=640 batch=48 device=1 name=result
# Out:
# Ultralytics 8.3.8 🚀 Python-3.10.14 torch-1.13.1+cu116 CUDA:1 (NVIDIA GeForce RTX 2080 Ti, 11020MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...
